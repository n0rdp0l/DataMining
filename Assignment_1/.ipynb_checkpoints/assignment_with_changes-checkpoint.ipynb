# %%
import pandas as pd
import numpy as np
import itertools 
import matplotlib.pyplot as plt

# %%
users = pd.read_csv(
    'ml-1m/users.dat',
    sep = "::",
    names = ['UserID', 'Gender', 'Age', 'Occupation', 'Zip-code'],
    encoding='latin-1',
    engine='python',
)

users.head()
# Out:
#    UserID Gender  Age  Occupation Zip-code
# 0       1      F    1          10    48067
# 1       2      M   56          16    70072
# 2       3      M   25          15    55117
# 3       4      M   45           7    02460
# 4       5      M   25          20    55455

# %%
movies = pd.read_csv(
    'ml-1m/movies.dat',
    sep = "::",
    names = ['MovieID', 'Title', 'Genres'],
    encoding='latin-1',
    engine='python',
)

movies.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings = pd.read_csv(
    'ml-1m/ratings.dat',
    sep = "::",
    names = ['UserID', 'MovieID', 'Rating', 'Timestamp'],
    encoding='latin-1',
    engine='python',
)

ratings.head()
# Out:
#    UserID  MovieID  Rating  Timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
a = pd.DataFrame(b, columns=['D','Colour', 'Value'])
a
# Out:
#   File "<ipython-input-253-e69dc58fe1d6>", line 1
#     a = pd.DataFrame(b, columns'ID', 'Colour', 'Value'])
#                                ^
# SyntaxError: invalid syntax

# %%
#MATRIX FACTORIZATION
# google colab / runtime - cambia tipo - GPU/TPU
x = ratings.sample(frac = 1)
X = np.array_split(x, 5)
learn_rate=0.005
reg=0.05
num_factors=10
num_iter=75

rmses = []
maes = []

for i in range(1):
    X_test = X[i]
    X_train = pd.concat([X[j] for j in range(5) if j!=i])
    train=X_train.pivot(index='MovieID', columns='UserID', values='Rating')
    test = X_test.pivot(index='MovieID', columns='UserID', values='Rating')
    
    M=np.random.rand(train.shape[0],num_factors)
    M=pd.DataFrame(M, index=train.index)
    U=np.random.rand(num_factors,train.shape[1])
    U=pd.DataFrame(U, columns=train.columns)
    
    indexes=train[train.notnull()].stack().index
    iterat=1
    rmse=100
    newrmse=99
    
    while (iterat < num_iter and newrmse-rmse < 0.01 ):
        print('Set: ' + str(i) + ', iteration: ' + str(iterat))
        iterat += 1
        for k in indexes:
            movie = M.loc[k[0],]
            user = U.loc[:,k[1]]
            x_hat = np.dot(movie,user)
            error = train.loc[k[0],k[1]] - x_hat
            M.loc[k[0],] = movie + learn_rate * (2*error*user - reg*movie)
            U.loc[:,k[1]] = user + learn_rate * (2*error*movie - reg*user)
            
        factoriz=pd.DataFrame(np.matmul(M, U), index=train.index, columns= train.columns)
        rmse=newrmse
        newrmse=np.sqrt(((factoriz[factoriz.columns & test.columns]-test)**2).mean().mean())
            
    #rmse = np.sqrt(np.mean((np.matmul(M, U)-train)**2))
    rmses += [newrmse]
    mae = abs(factoriz[factoriz.columns & test.columns]-test).mean().mean()
    maes += [mae]
# Out:
# Set: 0, iteration: 1
# <ipython-input-87-eab61733075a>:40: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   factoriz=pd.DataFrame(np.matmul(M, U), index=train.index, columns= train.columns)
# <ipython-input-87-eab61733075a>:42: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   newrmse=np.sqrt(((factoriz[factoriz.columns & test.columns]-test)**2).mean().mean())
# Set: 0, iteration: 2
# Set: 0, iteration: 3
# Set: 0, iteration: 4
# Set: 0, iteration: 5
# Set: 0, iteration: 6
# Set: 0, iteration: 7
# Set: 0, iteration: 8
# Set: 0, iteration: 9
# Set: 0, iteration: 10
# Set: 0, iteration: 11
# Set: 0, iteration: 12
# Set: 0, iteration: 13
# Set: 0, iteration: 14
# Set: 0, iteration: 15
# Set: 0, iteration: 16
# Set: 0, iteration: 17
# Set: 0, iteration: 18
# Set: 0, iteration: 19
# Set: 0, iteration: 20
# Set: 0, iteration: 21
# Set: 0, iteration: 22
# Set: 0, iteration: 23
# Set: 0, iteration: 24
# Set: 0, iteration: 25
# Set: 0, iteration: 26
# Set: 0, iteration: 27
# Set: 0, iteration: 28
# Set: 0, iteration: 29
# Set: 0, iteration: 30
# Set: 0, iteration: 31
# Set: 0, iteration: 32
# Set: 0, iteration: 33
# Set: 0, iteration: 34
# Set: 0, iteration: 35
# Set: 0, iteration: 36
# Set: 0, iteration: 37
# Set: 0, iteration: 38
# Set: 0, iteration: 39
# Set: 0, iteration: 40
# Set: 0, iteration: 41
# Set: 0, iteration: 42
# Set: 0, iteration: 43
# Set: 0, iteration: 44
# Set: 0, iteration: 45
# Set: 0, iteration: 46
# Set: 0, iteration: 47
# Set: 0, iteration: 48
# Set: 0, iteration: 49
# Set: 0, iteration: 50
# Set: 0, iteration: 51
# Set: 0, iteration: 52
# Set: 0, iteration: 53
# Set: 0, iteration: 54
# Set: 0, iteration: 55
# Set: 0, iteration: 56
# Set: 0, iteration: 57
# Set: 0, iteration: 58
# Set: 0, iteration: 59
# Set: 0, iteration: 60
# Set: 0, iteration: 61
# Set: 0, iteration: 62
# Set: 0, iteration: 63
# Set: 0, iteration: 64
# Set: 0, iteration: 65
# Set: 0, iteration: 66
# Set: 0, iteration: 67
# Set: 0, iteration: 68
# Set: 0, iteration: 69
# Set: 0, iteration: 70
# Set: 0, iteration: 71
# Set: 0, iteration: 72
# Set: 0, iteration: 73
# Set: 0, iteration: 74
# <ipython-input-87-eab61733075a>:46: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   mae = abs(factoriz[factoriz.columns & test.columns]-test).mean().mean()

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
# Start by visualizing users
pca = PCA(n_components=2)

PCs = pca.fit_transform(U.transpose())

# %%
# Visualize users labelled by genders
plt.figure(figsize=(10,10)) 

for gender in ['M', 'F']:
    mask = np.array(users[['Gender']] == gender)
    mask = [mask[i][0] for i in range(len(mask))]
    plt.scatter(PCs[mask, 0], PCs[mask, 1], label=gender, s=25, alpha=1)

plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left',fontsize=20)

# %%
users.loc[range(20),'Age']
# Out:
# 0      1
# 1     56
# 2     25
# 3     45
# 4     25
# 5     50
# 6     35
# 7     25
# 8     25
# 9     35
# 10    25
# 11    25
# 12    45
# 13    35
# 14    25
# 15    35
# 16    50
# 17    18
# 18     1
# 19    25
# Name: Age, dtype: int64

# %%
# Visualize users labelled by age
plt.figure(figsize=(10,10)) 
ages = np.unique(users['Age'])

for age in ages:
    mask = np.array(users[['Age']] == age)
    mask = [mask[i][0] for i in range(len(mask))]
    plt.scatter(PCs[mask, 0], PCs[mask, 1], label=age, s=25, alpha=1)

plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left',fontsize=20)

# %%
# Visualize movies labelled by genre

# %% [markdown]
# ### UMAP

# %%
import umap

# %%
umap = umap.UMAP()
X_m = umap.fit_transform(M)

# %%
plt.figure(figsize=(10,10)) 

for genre in genres:
    mask = np.array(genres == genre)
    plt.scatter(X_m[mask, 0], X_m[mask, 1], label=genre, s=25, alpha=1)

plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left',fontsize=20)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-228-e44a51be9d7d> in <module>
#       3 for genre in genres:
#       4     mask = np.array(genres == genre)
# ----> 5     plt.scatter(X_m[mask, 0], X_m[mask, 1], label=genre, s=25, alpha=1)
#       6
#       7 plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left',fontsize=20)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 3674 but corresponding boolean dimension is 3883

# %% [markdown]
# ### t-SNE

# %%
from sklearn.manifold import TSNE

# %%
t_sne = TSNE(n_components=2)
X_tsne = t_sne.fit_transform(train_in)

# %%
plt.figure(figsize=(10,10))

for i in range(10):
    mask = train_out == i
    plt.scatter(X_tsne[mask, 0], X_tsne[mask, 1], label=i, s=25, alpha=1)
plt.legend(bbox_to_anchor=(1.00, 1), loc='upper left', fontsize=20)

# %% [markdown]
# ## 1.3

# %%
Class = []
for i in train_in:
    Dis = []
    for j in range(10):
        Mean = means[j]
        dis = np.linalg.norm(Mean-i)
        Dis.append(dis)
    dis_min = np.amin(Dis)
    clas = float(np.where(Dis==dis_min)[0])
    Class.append(clas)

# %%
Class = np.array(Class)
diff = train_out-Class

# %%
success_rate = len(np.where(diff==0)[0])/len(train_out)
print(success_rate)
# Out:
# 0.8634232121922626

# %%
test_in = pd.read_csv("test_in.csv")
test_out = pd.read_csv("test_out.csv")
test_in = np.array(test_in)
test_out = np.array(test_out)

# %%
test_out = np.squeeze(test_out, axis=1)

# %%
Class_test = []
for i in test_in:
    Dis = []
    for j in range(10):
        Mean = means[j]
        dis = np.linalg.norm(Mean-i)
        Dis.append(dis)
    dis_min = np.amin(Dis)
    clas = float(np.where(Dis==dis_min)[0])
    Class_test.append(clas)

# %%
Class_test = np.array(Class_test)
diff_test = test_out - Class_test

# %%
success_rate_test = len(np.where(diff_test==0)[0])/len(test_out)
print(success_rate_test)
# Out:
# 0.8038038038038038

# %% [markdown]
# ## 1.4

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = len(train_in)/10

# %%
knn = KNeighborsClassifier(n_neighbors=12)

# %%
knn.fit(train_in, train_out)
knn_out = knn.predict(test_in)

# %%
diff_knn = knn_out - test_out
success_rate_test = len(np.where(diff_knn==0)[0])/len(test_out)
print(success_rate_test)
# Out:
# 0.8788788788788788

# %%
from sklearn.metrics import confusion_matrix
conf_m_knn = confusion_matrix(test_out, knn_out)

# %%
conf_m_simp = confusion_matrix(test_out, Class_test)

# %%
print(conf_m_knn)
print(conf_m_simp)
# Out:
# [[217   0   2   0   1   0   2   0   0   1]
#  [  0 119   0   0   0   0   2   0   0   0]
#  [  7   3  82   2   0   0   0   3   4   0]
#  [  5   0   1  69   0   1   0   0   1   2]
#  [  0   5   2   0  71   0   0   1   0   7]
#  [  7   0   1   8   2  32   0   2   0   3]
#  [  9   1   0   0   1   0  79   0   0   0]
#  [  0   4   0   1   2   0   0  56   0   1]
#  [  3   3   0   5   0   0   1   2  76   2]
#  [  1   2   0   0   1   0   0   6   1  77]]
# [[177   0   3   2   4   2  23   1  10   1]
#  [  0 120   0   0   0   0   1   0   0   0]
#  [  2   0  69   6   8   1   0   2  13   0]
#  [  3   0   3  61   1   8   0   0   1   2]
#  [  1   3   3   0  69   0   1   1   0   8]
#  [  3   0   0   6   3  38   1   0   0   4]
#  [  7   0   2   0   2   1  78   0   0   0]
#  [  0   2   1   0   5   0   0  50   0   6]
#  [  3   2   0   6   3   3   0   0  73   2]
#  [  0   5   0   0   8   0   0   5   2  68]]
